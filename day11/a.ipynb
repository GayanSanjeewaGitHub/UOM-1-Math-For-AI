# %%
from scipy.stats import binom
import numpy as np

binomal = binom.pmf(k=0, n=5, p=0.05)
print(1- binomal)
# Out:
# 0.22621906250000023

# %%
binomal = binom.cdf(k=3, n=20, p=0.05)
print(1- binomal)
# Out:
# 0.01590152601976358

# %%
binomal = binom.pmf(k=3, n=20, p=0.05)
